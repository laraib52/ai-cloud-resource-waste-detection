# %% [markdown]
# # Cloud ML Analysis
#
# ### Team Member: Luqman Fida
#
# This notebook demonstrates the complete Machine Learning workflow used in the AI Cloud Resource Waste Detection project.
#
# The notebook includes:
#
# - Data Loading
# - Data Exploration
# - Data Cleaning
# - Feature Engineering
# - AI Anomaly Detection using Isolation Forest
# - Cost Forecasting Results
# - Recommendation Generation

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

from prophet import Prophet

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Load Dataset
#
# In this section, the synthetic cloud resource dataset is loaded for preprocessing and machine learning analysis.

# %%
df = pd.read_csv("../data/raw/cloud_usage.csv")

df.head()
